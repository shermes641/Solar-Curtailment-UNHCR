# %%
from solarcurtailment import curtailment_calculation

# %%
# MODIFY THE FILE_PATH ACCORDING TO YOUR DIRECTORY FOR SAVING THE DATA FILES.
file_path = r"/Users/samhan/Downloads/data solar curtailment/data solar curtailment (after)" #for running in Samhan's laptop
file_path = r"E:\_UNHCR\CODE\Solar\data" #for running in TETB CEEM09 computer

#These samples represent (consecutively) tripping curtailment in a non clear sky day, tripping curtailment in a clear sky
#day, vvar curtailment, vwatt curtailment, incomplete datasample, and sample without curtailment.
for i in [1, 11, 14, 4, 5, 9]:
    sample_number = i
    print('Analyzing sample number {}'.format(i))
    data_file = '/data_sample_{}.csv'.format(sample_number)
    ghi_file = '/ghi_sample_{}.csv'.format(sample_number)

    curtailment_calculation.compute(file_path, data_file, ghi_file)
# Out:
# Analyzing sample number 1
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\curtailment_calculation.py:114: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_id = data['c_id'][0]
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\tripping_curt.py:654: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df['non_clear_sky_day_flag'] = 1
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\tripping_curt.py:688: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['polynomial_fit'] = z[0]*test['time_in_seconds']*test['time_in_seconds'] + \
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\tripping_curt.py:697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['ones'] = 1
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\tripping_curt.py:700: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,c = np.linalg.lstsq(A,y)[0]
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\tripping_curt.py:701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['y_line'] = c + m*test['cf']
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\tripping_curt.py:705: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['residuals'] = test['polynomial_fit'] - test['y_line']
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\tripping_curt.py:713: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_filtered['polynomial_fit'] = z[0]*test_filtered['time_in_seconds']*test_filtered['time_in_seconds'] + \
#    c_id        date  clear sky day  energy generated (kWh)  \
# 0   359  2019-09-03          False               11.227399
#
#    expected energy generated (kWh) estimation method tripping response  \
# 0                        16.042172            Linear               Yes
#
#    tripping curtailment (kWh) V-VAr response  V-VAr curtailment (kWh)  \
# 0                    4.814773           None                      0.0
#
#                           V-Watt response  V-Watt curtailment (kWh)
# 0  Inconclusive due to non clear sky day.                       NaN
# Analyzing sample number 11
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\curtailment_calculation.py:114: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_id = data['c_id'][0]
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\tripping_curt.py:652: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df['non_clear_sky_day_flag'] = 0
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\tripping_curt.py:688: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['polynomial_fit'] = z[0]*test['time_in_seconds']*test['time_in_seconds'] + \
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\tripping_curt.py:697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['ones'] = 1
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\tripping_curt.py:700: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,c = np.linalg.lstsq(A,y)[0]
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\tripping_curt.py:701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['y_line'] = c + m*test['cf']
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\tripping_curt.py:705: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['residuals'] = test['polynomial_fit'] - test['y_line']
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\tripping_curt.py:713: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_filtered['polynomial_fit'] = z[0]*test_filtered['time_in_seconds']*test_filtered['time_in_seconds'] + \
#    c_id        date  clear sky day  energy generated (kWh)  \
# 0    15  2020-01-17           True               28.463915
#
#    expected energy generated (kWh) estimation method tripping response  \
# 0                        33.126945           Polyfit               Yes
#
#    tripping curtailment (kWh) V-VAr response  V-VAr curtailment (kWh)  \
# 0                     4.66303           None                      0.0
#
#   V-Watt response  V-Watt curtailment (kWh)
# 0            None                         0
# Analyzing sample number 14
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\curtailment_calculation.py:114: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_id = data['c_id'][0]
#    c_id        date  clear sky day  energy generated (kWh)  \
# 0   361  2020-01-17           True               41.922012
#
#    expected energy generated (kWh) estimation method tripping response  \
# 0                        45.094723           Polyfit              None
#
#    tripping curtailment (kWh) V-VAr response  V-VAr curtailment (kWh)  \
# 0                           0            Yes                 3.172711
#
#   V-Watt response  V-Watt curtailment (kWh)
# 0            None                         0
# Analyzing sample number 4
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\curtailment_calculation.py:114: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_id = data['c_id'][0]
#    c_id        date  clear sky day  energy generated (kWh)  \
# 0   242  2020-04-13           True               31.951955
#
#    expected energy generated (kWh) estimation method tripping response  \
# 0                        36.438676           Polyfit              None
#
#    tripping curtailment (kWh) V-VAr response  V-VAr curtailment (kWh)  \
# 0                           0           None                      0.0
#
#   V-Watt response  V-Watt curtailment (kWh)
# 0             Yes                  4.486721
# Analyzing sample number 5
# Cannot analyze this sample due to incomplete data.
# Analyzing sample number 9
# e:\_UNHCR\CODE\.vfedot\Lib\site-packages\solarcurtailment\curtailment_calculation.py:114: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_id = data['c_id'][0]
#    c_id        date  clear sky day  energy generated (kWh)  \
# 0     4  2020-01-17           True               34.867516
#
#    expected energy generated (kWh) estimation method tripping response  \
# 0                        34.867516           Polyfit              None
#
#    tripping curtailment (kWh) V-VAr response  V-VAr curtailment (kWh)  \
# 0                           0           None                      0.0
#
#   V-Watt response  V-Watt curtailment (kWh)
# 0            None                         0
